# %%
# https://www.youtube.com/watch?v=i3uMhH2xeOM&ab_channel=Buynomics

# %%
# https://ngugijoan.medium.com/pricing-on-point-the-art-and-science-of-dynamic-pricing-dd543bf80f01
# https://ngugijoan.medium.com/dynamic-pricing-implementation-through-data-science-price-optimization-strategies-56adab4d3176
# https://levelup.gitconnected.com/calculating-individual-price-elasticity-for-products-9787e3b82875
# https://www.kaggle.com/code/arnabchaki/flight-fare-prediction-0-96-r2-score?fbclid=IwZXh0bgNhZW0CMTAAAR05L4by3xyhImYsDOnF-ufsQQ7VbBefv8Bg3ECHy1JHCR_XmjSZIAKM7yE_aem_AWdIsN4qMSlU9R0FQsAR9y8hT_e_ggs_tIfnGdUdpwA4mLwPAbLPidigOsMMcKNF-4wyLjSg2hcmqzefdb3gX5bT
# https://datascience.oneoffcoder.com/pricing-elasticity-modeling.html#Random-forest

# %%
import warnings
warnings.simplefilter("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # 9. Load data

# %%
df = pd.read_csv("02. Labeled_retail_data.csv")

# %%
df.shape
# Out:
# (763175, 11)

# %% [markdown]
# # 10. Clean data

# %%
Category_counts = df['Category'].value_counts()
Category_counts = Category_counts.sort_values(ascending=False)

# %%
Category_counts
# Out:
# Category
# Home and Garden                306881
# Kitchen                        133077
# Clothing and Accessories       131153
# Toys and Games                  93066
# Books and Stationery            57316
# Health and Beauty               26396
# Groceries                        9686
# Automotive                       3477
# Electronics                       829
# Sports and Outdoors               507
# Pets and Accessories              324
# Pets                              230
# Pets and Animals                  129
# Office Supplies                    47
# 1. Clothing and Accessories        28
# 2. Electronics                     28
# Beauty and Health                   1
# Name: count, dtype: int64

# %% [markdown]
# # 3. Exploratory data analysis (EDA)

# %%
df.sample(5)
# Out:
#         Invoice StockCode                          Description  Quantity  \
# 722338   577337     22734   SET OF 6 RIBBONS VINTAGE CHRISTMAS         1
# 524942   554933     22722    SET OF 6 SPICE TINS PANTRY DESIGN         3
# 371439   535978     21464  DISCO BALL ROTATOR BATTERY OPERATED         2
# 572381   561242     22726           ALARM CLOCK BAKELIKE GREEN        12
# 476110   548012     21506             FANCY FONT BIRTHDAY CARD        12
#
#                 InvoiceDate  Price  Customer ID         Country  \
# 722338  2011-11-18 14:51:00   2.89      15494.0  United Kingdom
# 524942  2011-05-27 13:26:00   3.95      13232.0  United Kingdom
# 371439  2010-11-29 13:00:00   4.25      17049.0  United Kingdom
# 572381  2011-07-26 11:05:00   3.75      16258.0  United Kingdom
# 476110  2011-03-29 11:15:00   0.42      17377.0  United Kingdom
#
#         profit_margin  Cost_price                  Category
# 722338       0.262016    2.132773  Clothing and Accessories
# 524942       0.097185    3.566121                   Kitchen
# 371439       0.367834    2.686705            Toys and Games
# 572381       0.036877    3.611710           Home and Garden
# 476110       0.484168    0.216649      Books and Stationery

# %%
Category_counts = df['Category'].value_counts().head(100)
Category_counts = Category_counts.sort_values(ascending=False)

# %%
Category_counts
# Out:
# Category
# Home and Garden                306881
# Kitchen                        133077
# Clothing and Accessories       131153
# Toys and Games                  93066
# Books and Stationery            57316
# Health and Beauty               26396
# Groceries                        9686
# Automotive                       3477
# Electronics                       829
# Sports and Outdoors               507
# Pets and Accessories              324
# Pets                              230
# Pets and Animals                  129
# Office Supplies                    47
# 1. Clothing and Accessories        28
# 2. Electronics                     28
# Beauty and Health                   1
# Name: count, dtype: int64

# %% [markdown]
# Top 100 Count of Transactions by Description

# %%
description_counts = df['Description'].value_counts().head(100)
description_counts = description_counts.sort_values(ascending=False)

# %%
description_counts
# Out:
# Description
# REGENCY CAKESTAND 3 TIER            3428
# ASSORTED COLOUR BIRD ORNAMENT       2777
# REX CASH+CARRY JUMBO SHOPPER        2141
# PARTY BUNTING                       2121
# LUNCH BAGBLACK SKULL.               2117
#                                     ...
# SET OF 4 PANTRY JELLY MOULDS         893
# RIBBON REEL STRIPES DESIGN           892
# POTTERING IN THE SHED METAL SIGN     885
# EDWARDIAN PARASOL NATURAL            879
# WOODEN SCHOOL COLOURING SET          876
# Name: count, Length: 100, dtype: int64

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x=description_counts.index, y=description_counts.values, palette='viridis')
plt.title('Top 100 Count of Transactions by Description')
plt.xlabel('Description')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Top 100 Count of Transactions by Invoice

# %%
invoice_counts = df['Invoice'].value_counts().head(100)
invoice_counts = invoice_counts.sort_values(ascending=False)

# %%
plt.figure(figsize=(14, 8))
sns.barplot(x=invoice_counts.index, y=invoice_counts.values, palette='viridis')
plt.title('Top 100 Count of Transactions by Invoice')
plt.xlabel('Invoice')
plt.ylabel('Count')
plt.xticks(rotation=90) 
plt.show()

# %% [markdown]
# # 4. Manipulate cost for optimization model

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 3  489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 5  489434     22064            PINK DOUGHNUT TRINKET POT        24
# 6  489434     21871                  SAVE THE PLANET MUG        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 5 2009-12-01 07:45:00   1.65      13085.0  United Kingdom
# 6 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %%
np.random.seed(42)
df['profit_margin'] = np.random.uniform(0.01, 0.5, size=len(df))

# %%
df['Cost_price'] = df['Price'] * (1 - df['profit_margin'])

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 3  489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 5  489434     22064            PINK DOUGHNUT TRINKET POT        24
# 6  489434     21871                  SAVE THE PLANET MUG        24
#
#           InvoiceDate  Price  Customer ID         Country  profit_margin  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom       0.193525
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom       0.475850
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom       0.368677
# 5 2009-12-01 07:45:00   1.65      13085.0  United Kingdom       0.303343
# 6 2009-12-01 07:45:00   1.25      13085.0  United Kingdom       0.086449
#
#    Cost_price
# 0    5.605004
# 1    3.538012
# 3    1.325778
# 5    1.149485
# 6    1.141939

# %% [markdown]
# # 5. Feature engineering

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 3  489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 5  489434     22064            PINK DOUGHNUT TRINKET POT        24
# 6  489434     21871                  SAVE THE PLANET MUG        24
#
#           InvoiceDate  Price  Customer ID         Country  profit_margin  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom       0.193525
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom       0.475850
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom       0.368677
# 5 2009-12-01 07:45:00   1.65      13085.0  United Kingdom       0.303343
# 6 2009-12-01 07:45:00   1.25      13085.0  United Kingdom       0.086449
#
#    Cost_price
# 0    5.605004
# 1    3.538012
# 3    1.325778
# 5    1.149485
# 6    1.141939

# %%
df['yyyymmdd'] = df['InvoiceDate'].dt.strftime('%Y%m%d')

# %%
df.drop(columns='InvoiceDate', axis = 'columns')
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1       489434    79323P                   PINK CHERRY LIGHTS        12
# 3       489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 5       489434     22064            PINK DOUGHNUT TRINKET POT        24
# 6       489434     21871                  SAVE THE PLANET MUG        24
# ...        ...       ...                                  ...       ...
# 541902  581587     22629                   SPACEBOY LUNCH BOX        12
# 541904  581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138         BAKING SET 9 PIECE RETROSPOT         3
# 541909  581587      POST                              POSTAGE         1
#
#         Price  Customer ID         Country  profit_margin  Cost_price  \
# 0        6.95      13085.0  United Kingdom       0.193525    5.605004
# 1        6.75      13085.0  United Kingdom       0.475850    3.538012
# 3        2.10      13085.0  United Kingdom       0.368677    1.325778
# 5        1.65      13085.0  United Kingdom       0.303343    1.149485
# 6        1.25      13085.0  United Kingdom       0.086449    1.141939
# ...       ...          ...             ...            ...         ...
# 541902   1.95      12680.0          France       0.124120    1.707966
# 541904   0.85      12680.0          France       0.233201    0.651779
# 541907   4.15      12680.0          France       0.490437    2.114687
# 541908   4.95      12680.0          France       0.162800    4.144142
# 541909  18.00      12680.0          France       0.245608   13.579051
#
#         yyyymmdd
# 0       20091201
# 1       20091201
# 3       20091201
# 5       20091201
# 6       20091201
# ...          ...
# 541902  20111209
# 541904  20111209
# 541907  20111209
# 541908  20111209
# 541909  20111209
#
# [602618 rows x 10 columns]

# %% [markdown]
# datetime features

# %%
def datetime_feature_extraction(df):
    # Day extraction
    df['dayofweek'] = df['InvoiceDate'].dt.dayofweek
    df['dayofmonth'] = df['InvoiceDate'].dt.day
    df['dayofyear'] = df['InvoiceDate'].dt.dayofyear
    df['is_weekend'] = (df['InvoiceDate'].dt.dayofweek >= 5).astype(int)
    df['weekday_weekend'] = df['InvoiceDate'].dt.dayofweek.apply(lambda x: 0 if x >= 5 else 1)

    # Week extraction
    df['weekofyear'] = df['InvoiceDate'].dt.isocalendar().week
    df['weekofmonth'] = np.ceil(df['dayofmonth'] / 7).astype(int)    
    
    # Month extraction
    df['month'] = df['InvoiceDate'].dt.month
    df['quarter'] = df['InvoiceDate'].dt.quarter
    df['days_in_month'] = df['InvoiceDate'].dt.days_in_month

    # Year extraction
    df['year'] = df['InvoiceDate'].dt.year-2009
    return df

# %%
df = datetime_feature_extraction(df)

# %% [markdown]
# group by

# %%
aggregation_functions = {
    'Quantity': 'sum',
    'Price': 'mean',
    'Cost_price':'mean',
    'dayofweek': 'max',
    'dayofmonth': 'max',
    'dayofyear': 'max',
    'is_weekend': 'max',
    'weekday_weekend': 'max',
    'weekofyear': 'max',
    'weekofmonth': 'max',
    'month': 'max',
    'quarter': 'max',
    'days_in_month': 'max',
    'year': 'max'
}

# %%
df = df.groupby(['StockCode','Description','yyyymmdd']).agg(aggregation_functions).reset_index()

# %%
df.head()
# Out:
#   StockCode                 Description  yyyymmdd  Quantity  Price  \
# 0     10002  INFLATABLE POLITICAL GLOBE  20091201        12   0.85
# 1     10002  INFLATABLE POLITICAL GLOBE  20091203         7   0.85
# 2     10002  INFLATABLE POLITICAL GLOBE  20091204        73   0.85
# 3     10002  INFLATABLE POLITICAL GLOBE  20091206        49   0.85
# 4     10002  INFLATABLE POLITICAL GLOBE  20091207         2   0.85
#
#    Cost_price  dayofweek  dayofmonth  dayofyear  is_weekend  weekday_weekend  \
# 0    0.770477          1           1        335           0                1
# 1    0.651868          3           3        337           0                1
# 2    0.595542          4           4        338           0                1
# 3    0.560934          6           6        340           1                0
# 4    0.627406          0           7        341           0                1
#
#    weekofyear  weekofmonth  month  quarter  days_in_month  year
# 0          49            1     12        4             31     0
# 1          49            1     12        4             31     0
# 2          49            1     12        4             31     0
# 3          49            1     12        4             31     0
# 4          50            1     12        4             31     0

# %% [markdown]
# Create change

# %%
df['change_qty'] = df['Quantity'].pct_change()

# %%
df['change_price'] = df['Price'].pct_change()

# %%
df.dropna(inplace=True)

# %%
df.sample(10)
# Out:
#        StockCode                         Description  yyyymmdd  Quantity  \
# 73788      21695      SMALL SILVER FLOWER CANDLE POT  20110925         6
# 15087      20845   ZINC HEART LATTICE 2 WALL PLANTER  20110719         6
# 29467      21108  FAIRY CAKE FLANNEL ASSORTED COLOUR  20100715         9
# 48802      21380       WOODEN HAPPY BIRTHDAY GARLAND  20100728        10
# 90365      21876                       POTTERING MUG  20100301         6
# 100911     21931              JUMBO STORAGE BAG SUKI  20110121        16
# 252828     35953  FOLKART STAR CHRISTMAS DECORATIONS  20111206        36
# 291641   15056BL             EDWARDIAN PARASOL BLACK  20101118         1
# 264209     82552                 WASHROOM METAL SIGN  20100224         1
# 218573     22938            CUPCAKE LACE PAPER SET 6  20110717         4
#
#         Price  Cost_price  dayofweek  dayofmonth  dayofyear  is_weekend  \
# 73788    2.95    1.568827          6          25        268           1
# 15087    6.35    4.153454          1          19        200           0
# 29467    2.55    1.856098          3          15        196           0
# 48802    2.95    2.048778          2          28        209           0
# 90365    1.25    0.808618          0           1         60           0
# 100911   1.95    1.480082          4          21         21           0
# 252828   0.39    0.266546          1           6        340           0
# 291641   5.95    3.575584          3          18        322           0
# 264209   1.25    0.729449          2          24         55           0
# 218573   1.95    1.675925          6          17        198           1
#
#         weekday_weekend  weekofyear  weekofmonth  month  quarter  \
# 73788                 0          38            4      9        3
# 15087                 1          29            3      7        3
# 29467                 1          28            3      7        3
# 48802                 1          30            4      7        3
# 90365                 1           9            1      3        1
# 100911                1           3            3      1        1
# 252828                1          49            1     12        4
# 291641                1          46            3     11        4
# 264209                1           8            4      2        1
# 218573                0          28            3      7        3
#
#         days_in_month  year  change_qty  change_price
# 73788              30     2    0.000000  0.000000e+00
# 15087              31     2    2.000000  0.000000e+00
# 29467              31     1   -0.800000  0.000000e+00
# 48802              31     1    4.000000  2.220446e-16
# 90365              31     1    5.000000  0.000000e+00
# 100911             31     2    7.000000  0.000000e+00
# 252828             31     2   -0.625000  2.220446e-16
# 291641             30     1   -0.923077  0.000000e+00
# 264209             28     1   -0.888889  0.000000e+00
# 218573             31     2   -0.666667  0.000000e+00

# %% [markdown]
# # 5. Get current price

# %%
df.sort_values(by=['Description', 'yyyymmdd'], ascending=[True, False], inplace=True)

# %%
df['row_number'] = df.groupby('Description').cumcount() + 1

# %%
df.head()
# Out:
#        StockCode                 Description  yyyymmdd  Quantity  Price  \
# 159471     22436  12 COLOURED PARTY BALLOONS  20111207        20   0.65
# 159470     22436  12 COLOURED PARTY BALLOONS  20111206         2   0.65
# 159469     22436  12 COLOURED PARTY BALLOONS  20111205        21   0.65
# 159468     22436  12 COLOURED PARTY BALLOONS  20111130        50   0.65
# 159467     22436  12 COLOURED PARTY BALLOONS  20111129        40   0.65
#
#         Cost_price  dayofweek  dayofmonth  dayofyear  is_weekend  \
# 159471    0.496619          2           7        341           0
# 159470    0.513294          1           6        340           0
# 159469    0.465913          0           5        339           0
# 159468    0.440071          2          30        334           0
# 159467    0.575201          1          29        333           0
#
#         weekday_weekend  weekofyear  weekofmonth  month  quarter  \
# 159471                1          49            1     12        4
# 159470                1          49            1     12        4
# 159469                1          49            1     12        4
# 159468                1          48            5     11        4
# 159467                1          48            5     11        4
#
#         days_in_month  year  change_qty  change_price  row_number
# 159471             31     2    9.000000           0.0           1
# 159470             31     2   -0.904762           0.0           2
# 159469             31     2   -0.580000           0.0           3
# 159468             30     2    0.250000           0.0           4
# 159467             30     2    3.000000           0.0           5

# %% [markdown]
# lastest price

# %%
df_price = df[df['row_number'] == 1][['yyyymmdd','StockCode','Description','Price','Cost_price','Quantity']]

# %%
df_price.head()
# Out:
#         yyyymmdd StockCode                       Description  Price  \
# 159471  20111207     22436        12 COLOURED PARTY BALLOONS   0.65
# 54501   20111016     21448         12 DAISY PEGS IN WOOD BOX   1.65
# 141793  20111208     22282         12 EGG HOUSE PAINTED WOOD  12.75
# 248387  20111207     23442      12 HANGING EGGS HAND PAINTED   2.08
# 54351   20110911     21447  12 IVORY ROSE PEG PLACE SETTINGS   1.25
#
#         Cost_price  Quantity
# 159471    0.496619        20
# 54501     1.194302         2
# 141793   10.751697         2
# 248387    1.606553        10
# 54351     0.945495         9

# %% [markdown]
# # 6. Model

# %%
df.head()
# Out:
#        StockCode                 Description  yyyymmdd  Quantity  Price  \
# 159471     22436  12 COLOURED PARTY BALLOONS  20111207        20   0.65
# 159470     22436  12 COLOURED PARTY BALLOONS  20111206         2   0.65
# 159469     22436  12 COLOURED PARTY BALLOONS  20111205        21   0.65
# 159468     22436  12 COLOURED PARTY BALLOONS  20111130        50   0.65
# 159467     22436  12 COLOURED PARTY BALLOONS  20111129        40   0.65
#
#         Cost_price  dayofweek  dayofmonth  dayofyear  is_weekend  \
# 159471    0.496619          2           7        341           0
# 159470    0.513294          1           6        340           0
# 159469    0.465913          0           5        339           0
# 159468    0.440071          2          30        334           0
# 159467    0.575201          1          29        333           0
#
#         weekday_weekend  weekofyear  weekofmonth  month  quarter  \
# 159471                1          49            1     12        4
# 159470                1          49            1     12        4
# 159469                1          49            1     12        4
# 159468                1          48            5     11        4
# 159467                1          48            5     11        4
#
#         days_in_month  year  change_qty  change_price  row_number
# 159471             31     2    9.000000           0.0           1
# 159470             31     2   -0.904762           0.0           2
# 159469             31     2   -0.580000           0.0           3
# 159468             30     2    0.250000           0.0           4
# 159467             30     2    3.000000           0.0           5

# %% [markdown]
# create 1 model each SKU

# %%
df_sku = df[df['Description'] == 'REGENCY CAKESTAND 3 TIER']

# %%
df_sku.drop(columns=['StockCode','Description','yyyymmdd','Quantity','Price','Cost_price','row_number'], axis='columns', inplace=True)

# %%
df_sku
# Out:
#         dayofweek  dayofmonth  dayofyear  is_weekend  weekday_weekend  \
# 157076          4           9        343           0                1
# 157075          3           8        342           0                1
# 157074          2           7        341           0                1
# 157073          1           6        340           0                1
# 157072          0           5        339           0                1
# ...           ...         ...        ...         ...              ...
# 156574          4          19         78           0                1
# 156573          3          18         77           0                1
# 156572          2          17         76           0                1
# 156571          1          16         75           0                1
# 156570          0          15         74           0                1
#
#         weekofyear  weekofmonth  month  quarter  days_in_month  year  \
# 157076          49            2     12        4             31     2
# 157075          49            2     12        4             31     2
# 157074          49            1     12        4             31     2
# 157073          49            1     12        4             31     2
# 157072          49            1     12        4             31     2
# ...            ...          ...    ...      ...            ...   ...
# 156574          11            3      3        1             31     1
# 156573          11            3      3        1             31     1
# 156572          11            3      3        1             31     1
# 156571          11            3      3        1             31     1
# 156570          11            3      3        1             31     1
#
#         change_qty  change_price
# 157076   -0.375000      0.000000
# 157075   -0.876923      0.064401
# 157074   -0.109589     -0.041166
# 157073    3.424242     -0.101664
# 157072    2.300000      0.090719
# ...            ...           ...
# 156574    1.904762     -0.015686
# 156573    0.000000      0.000000
# 156572   -0.461538      0.017964
# 156571    3.875000     -0.017647
# 156570   -0.859649    105.250000
#
# [507 rows x 13 columns]

# %% [markdown]
# split X and y

# %%
X = df_sku.drop(columns=['change_qty'])
y = df_sku['change_qty']

# %% [markdown]
# model training

# %%
rt = DecisionTreeRegressor(random_state=42)

# %%
param_grid = {
    'max_depth': [None, 2, 5, 10, 15],
    'min_samples_split': [2, 5, 10, 15],
    'min_samples_leaf': [1, 2, 5, 10]
}

# %%
grid_search = GridSearchCV(estimator=rt, param_grid=param_grid, cv=10, scoring='neg_mean_squared_error', verbose=2, n_jobs=-1)

# %%
grid_search.fit(X, y)
# Out:
# Fitting 10 folds for each of 80 candidates, totalling 800 fits
# GridSearchCV(cv=10, estimator=DecisionTreeRegressor(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [None, 2, 5, 10, 15],
#                          'min_samples_leaf': [1, 2, 5, 10],
#                          'min_samples_split': [2, 5, 10, 15]},
#              scoring='neg_mean_squared_error', verbose=2)

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeRegressor(max_depth=2, min_samples_leaf=10, random_state=42)

# %%
grid_search.best_score_
# Out:
# -38.26922684484992

# %% [markdown]
# save model

# %%
best_model = grid_search.best_estimator_

# %% [markdown]
# # 7. Optimize

# %% [markdown]
# random point of time

# %%
df_sku_optimize = df_sku[['dayofweek','dayofmonth','dayofyear','is_weekend','weekday_weekend','weekofyear','weekofmonth','month','quarter','days_in_month','year']].sample(1)

# %%
multipliers = [round(x * 0.01, 2) for x in range(-50, 51)]

# %%
df_sku_optimize = df_sku_optimize.loc[np.repeat(df_sku_optimize.index.values, len(multipliers))]

# %%
df_sku_optimize['change_price'] = multipliers

# %%
df_sku_optimize.head()
# Out:
#         dayofweek  dayofmonth  dayofyear  is_weekend  weekday_weekend  \
# 156967          6          31        212           1                0
# 156967          6          31        212           1                0
# 156967          6          31        212           1                0
# 156967          6          31        212           1                0
# 156967          6          31        212           1                0
#
#         weekofyear  weekofmonth  month  quarter  days_in_month  year  \
# 156967          30            5      7        3             31     2
# 156967          30            5      7        3             31     2
# 156967          30            5      7        3             31     2
# 156967          30            5      7        3             31     2
# 156967          30            5      7        3             31     2
#
#         change_price
# 156967         -0.50
# 156967         -0.49
# 156967         -0.48
# 156967         -0.47
# 156967         -0.46

# %% [markdown]
# optimize

# %%
change_price_list = []

# %%
for i in range(df_sku_optimize.shape[0]):
    demand_change = best_model.predict(df_sku_optimize.iloc[[i]])
    change_price_list.append(demand_change[0])

# %%
df_sku_optimize['change_qty'] = change_price_list

# %%
initial_price = df_price[df_price['Description'] == 'REGENCY CAKESTAND 3 TIER']['Price'].iloc[0]
initial_cost_price = df_price[df_price['Description'] == 'REGENCY CAKESTAND 3 TIER']['Cost_price'].iloc[0]
initial_quantity = df_price[df_price['Description'] == 'REGENCY CAKESTAND 3 TIER']['Quantity'].iloc[0]

# %%
initial_price
# Out:
# 12.75

# %%
df_sku_optimize['price_new'] = initial_price*(1+df_sku_optimize['change_price'])

# %%
df_sku_optimize['qty_new'] = initial_quantity*(1+df_sku_optimize['change_qty'])

# %%
df_sku_optimize['additional_profit'] = df_sku_optimize['qty_new']*(df_sku_optimize['price_new']-initial_cost_price)

# %%
df_sku_optimize.head()
# Out:
#         dayofweek  dayofmonth  dayofyear  is_weekend  weekday_weekend  \
# 156967          6          31        212           1                0
# 156967          6          31        212           1                0
# 156967          6          31        212           1                0
# 156967          6          31        212           1                0
# 156967          6          31        212           1                0
#
#         weekofyear  weekofmonth  month  quarter  days_in_month  year  \
# 156967          30            5      7        3             31     2
# 156967          30            5      7        3             31     2
# 156967          30            5      7        3             31     2
# 156967          30            5      7        3             31     2
# 156967          30            5      7        3             31     2
#
#         change_price  change_qty  price_new    qty_new  additional_profit
# 156967         -0.50     2.84116     6.3750  38.411598        -104.058816
# 156967         -0.49     2.84116     6.5025  38.411598         -99.161338
# 156967         -0.48     2.84116     6.6300  38.411598         -94.263859
# 156967         -0.47     2.84116     6.7575  38.411598         -89.366380
# 156967         -0.46     2.84116     6.8850  38.411598         -84.468901

# %% [markdown]
# select max additional profit

# %%
df_sku_optimize[df_sku_optimize['additional_profit'] == df_sku_optimize['additional_profit'].max()]
# Out:
#         dayofweek  dayofmonth  dayofyear  is_weekend  weekday_weekend  \
# 156967          6          31        212           1                0
#
#         weekofyear  weekofmonth  month  quarter  days_in_month  year  \
# 156967          30            5      7        3             31     2
#
#         change_price  change_qty  price_new    qty_new  additional_profit
# 156967         -0.03     2.84116    12.3675  38.411598         126.122686
