# %%
import warnings
warnings.simplefilter("ignore")

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. Load data

# %%
df_2009_2010 = pd.read_excel("online_retail_II.xlsx", sheet_name='Year 2009-2010')

# %%
df_2010_2011 = pd.read_excel("online_retail_II.xlsx", sheet_name='Year 2010-2011')

# %%
df = pd.concat([df_2009_2010, df_2010_2011])

# %%
df.shape
# Out:
# (1067371, 8)

# %% [markdown]
# # 2. Check data quality

# %% [markdown]
# data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1067371 entries, 0 to 541909
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  datetime64[ns]
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 73.3+ MB

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %% [markdown]
# columns name

# %%
df.columns
# Out:
# Index(['Invoice', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'Price', 'Customer ID', 'Country'],
#       dtype='object')

# %% [markdown]
# data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1067371 entries, 0 to 541909
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  datetime64[ns]
#  5   Price        1067371 non-null  float64
#  6   Customer ID  824364 non-null   float64
#  7   Country      1067371 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 73.3+ MB

# %% [markdown]
# check missing value

# %%
df.isna().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4382
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    243007
# Country             0
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# check white space

# %%
def empty_or_whitespace_strings(df):
    string_columns = df.select_dtypes(include=['object']).columns
    empty_whitespace_check = df[string_columns].applymap(lambda x: isinstance(x, str) and x.isspace())

    count_empty_whitespace = empty_whitespace_check.sum()
    rows_with_whitespace_indices = empty_whitespace_check.any(axis=1)
    list_row_with_whilespace_indices = df.index[rows_with_whitespace_indices].tolist()

    return count_empty_whitespace, list_row_with_whilespace_indices

# %%
show_whilespace, indices_whilesapce = empty_or_whitespace_strings(df)

# %%
show_whilespace
# Out:
# Invoice        0
# StockCode      0
# Description    0
# Country        0
# dtype: int64

# %% [markdown]
# check unique value

# %%
for i in df.columns:
    print('Columns name: ', i)
    print('Unique value: ', df[i].unique())
    print('Count unique value: ', df[i].nunique())
    print('-'*10)
# Out:
# Columns name:  Invoice
# Unique value:  [489434 489435 489436 ... 581585 581586 581587]
# Count unique value:  44876
# ----------
# Columns name:  StockCode
# Unique value:  [85048 '79323P' '79323W' ... 23562 23561 23843]
# Count unique value:  4646
# ----------
# Columns name:  Description
# Unique value:  ['15CM CHRISTMAS GLASS BALL 20 LIGHTS' 'PINK CHERRY LIGHTS'
#  ' WHITE CHERRY LIGHTS' ... 'SILVER AND BLACK ORBIT NECKLACE'
#  'CREAM HANGING HEART T-LIGHT HOLDER' 'PAPER CRAFT , LITTLE BIRDIE']
# Count unique value:  5299
# ----------
# Columns name:  Quantity
# Unique value:  [    12     48     24     10     18      3     16      4      2      6
#       8      1     28     30     60     32     56      9     25     36
#      20    -12     -6     -4    -24     -3     -2    576    288     27
#      64    160      5     -1     72     50     54      7    800     11
#      58    192     96    144    100    180    216     15    240    108
#      33     90     81    -81    -48     17     -5     40     -8     -9
#      13     21    120    200    168     19    280    128   -150    -18
#     -23     80    300    450     14     61    480     -7     46    504
#      45   4320   5184   4008     22    600    505    500     23     47
#     432    252     75    -16   -504   -600   -252   -246    -36    360
#     107     49     42     66    -10     34     52    400     70    936
#     -32    -60    -96    -50   -120     35    -64   -168    -30    256
#    1500    320    130   1002     26   1080     29    -13     67    960
#     864    150    126    468    336   3000    -25     38    208    334
#     124    125    117   -200     39    -20     55    -11     78   -100
#     -17   -144     77    350    526     98    112     59     37    -14
#     408   1440    832    624    204    198    608    224     43     65
#     720    271     41    264    225    104    163    187    312    164
#     110   -190    250    -72    284     89    118   -400   6012    866
#  ...
#  '2011-12-09 12:09:00', '2011-12-09 12:16:00', '2011-12-09 12:19:00',
#  '2011-12-09 12:20:00', '2011-12-09 12:21:00', '2011-12-09 12:23:00',
#  '2011-12-09 12:25:00', '2011-12-09 12:31:00', '2011-12-09 12:49:00',
#  '2011-12-09 12:50:00']
# Length: 41439, dtype: datetime64[ns]
# Count unique value:  41439
# ----------
# Columns name:  Price
# Unique value:  [  6.95   6.75   2.1  ...  13.35   4.76 224.69]
# Count unique value:  1022
# ----------
# Columns name:  Customer ID
# Unique value:  [13085. 13078. 15362. ... 15520. 13298. 12713.]
# Count unique value:  5942
# ----------
# Columns name:  Country
# Unique value:  ['United Kingdom' 'France' 'USA' 'Belgium' 'Australia' 'EIRE' 'Germany'
#  'Portugal' 'Japan' 'Denmark' 'Netherlands' 'Poland' 'Spain'
#  'Channel Islands' 'Italy' 'Cyprus' 'Greece' 'Norway' 'Austria' 'Sweden'
#  'United Arab Emirates' 'Finland' 'Switzerland' 'Unspecified' 'Nigeria'
#  'Malta' 'RSA' 'Singapore' 'Bahrain' 'Thailand' 'Israel' 'Lithuania'
#  'West Indies' 'Korea' 'Brazil' 'Canada' 'Iceland' 'Lebanon'
#  'Saudi Arabia' 'Czech Republic' 'European Community']
# Count unique value:  41
# ----------

# %% [markdown]
# Quantity and Price > 0

# %%
df = df[df['Quantity'] > 0]

# %%
df = df[df['Price'] > 0]

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# check Description

# %%
description_counts = df.groupby('StockCode').agg(number_description=('Description', pd.Series.nunique)).reset_index()

# %%
multiple_descriptions = description_counts[description_counts['number_description'] > 1]

# %%
multiple_descriptions = multiple_descriptions.sort_values("number_description", ascending=False)

# %%
multiple_descriptions
# Out:
#          StockCode  number_description
# 1423         22345                   4
# 1458         22384                   4
# 1422         22344                   4
# 2275         23236                   4
# 2235         23196                   4
# ...            ...                 ...
# 1493         22425                   2
# 1500         22432                   2
# 1501         22433                   2
# 1513         22445                   2
# 4621  BANK CHARGES                   2
#
# [624 rows x 2 columns]

# %%
df[df['StockCode'] == 22345]
# Out:
#        Invoice StockCode                        Description  Quantity  \
# 3763    489784     22345  PARTY PIZZA DISH BLUE+WHITE SPOT         12
# 7287    490017     22345  PARTY PIZZA DISH BLUE WHITE SPOT          6
# 17494   490786     22345  PARTY PIZZA DISH BLUE+WHITE SPOT         12
# 81546   496882     22345  PARTY PIZZA DISH BLUE WHITE SPOT          1
# 88014   497615     22345  PARTY PIZZA DISH BLUE WHITE SPOT          6
# ...        ...       ...                                ...       ...
# 526151  580652     22345     PARTY PIZZA DISH BLUE POLKADOT       144
# 526490  580671     22345     PARTY PIZZA DISH BLUE POLKADOT        24
# 530028  580771     22345     PARTY PIZZA DISH BLUE POLKADOT         6
# 533144  581015     22345     PARTY PIZZA DISH BLUE POLKADOT        24
# 539987  581453     22345     PARTY PIZZA DISH BLUE POLKADOT        24
#
#                InvoiceDate  Price  Customer ID         Country
# 3763   2009-12-02 11:48:00   0.85      13269.0  United Kingdom
# 7287   2009-12-03 12:31:00   0.85      14159.0  United Kingdom
# 17494  2009-12-08 11:23:00   0.85      15079.0  United Kingdom
# 81546  2010-02-04 14:13:00   0.85      15167.0  United Kingdom
# 88014  2010-02-11 11:59:00   0.85      14527.0  United Kingdom
# ...                    ...    ...          ...             ...
# 526151 2011-12-05 13:33:00   0.19      17511.0  United Kingdom
# 526490 2011-12-05 14:26:00   0.19      15159.0  United Kingdom
# 530028 2011-12-06 10:58:00   0.19      16015.0  United Kingdom
# 533144 2011-12-07 09:35:00   0.19      13949.0  United Kingdom
# 539987 2011-12-08 18:15:00   0.19      16401.0  United Kingdom
#
# [86 rows x 8 columns]

# %%
def fix_duplicates_description(df):
    df['Description'] = df.groupby('StockCode')['Description'].transform('first')
    return df

# %%
df = fix_duplicates_description(df)

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# check Description (again)

# %%
description_counts = df.groupby('StockCode').agg(number_description=('Description', pd.Series.nunique)).reset_index()

# %%
multiple_descriptions = description_counts[description_counts['number_description'] > 1]

# %%
multiple_descriptions = multiple_descriptions.sort_values("number_description", ascending=False)

# %%
multiple_descriptions
# Out:
# Empty DataFrame
# Columns: [StockCode, number_description]
# Index: []

# %%
df[df['StockCode'] == 22345]
# Out:
#        Invoice StockCode                        Description  Quantity  \
# 3763    489784     22345  PARTY PIZZA DISH BLUE+WHITE SPOT         12
# 7287    490017     22345  PARTY PIZZA DISH BLUE+WHITE SPOT          6
# 17494   490786     22345  PARTY PIZZA DISH BLUE+WHITE SPOT         12
# 81546   496882     22345  PARTY PIZZA DISH BLUE+WHITE SPOT          1
# 88014   497615     22345  PARTY PIZZA DISH BLUE+WHITE SPOT          6
# ...        ...       ...                                ...       ...
# 526151  580652     22345  PARTY PIZZA DISH BLUE+WHITE SPOT        144
# 526490  580671     22345  PARTY PIZZA DISH BLUE+WHITE SPOT         24
# 530028  580771     22345  PARTY PIZZA DISH BLUE+WHITE SPOT          6
# 533144  581015     22345  PARTY PIZZA DISH BLUE+WHITE SPOT         24
# 539987  581453     22345  PARTY PIZZA DISH BLUE+WHITE SPOT         24
#
#                InvoiceDate  Price  Customer ID         Country
# 3763   2009-12-02 11:48:00   0.85      13269.0  United Kingdom
# 7287   2009-12-03 12:31:00   0.85      14159.0  United Kingdom
# 17494  2009-12-08 11:23:00   0.85      15079.0  United Kingdom
# 81546  2010-02-04 14:13:00   0.85      15167.0  United Kingdom
# 88014  2010-02-11 11:59:00   0.85      14527.0  United Kingdom
# ...                    ...    ...          ...             ...
# 526151 2011-12-05 13:33:00   0.19      17511.0  United Kingdom
# 526490 2011-12-05 14:26:00   0.19      15159.0  United Kingdom
# 530028 2011-12-06 10:58:00   0.19      16015.0  United Kingdom
# 533144 2011-12-07 09:35:00   0.19      13949.0  United Kingdom
# 539987 2011-12-08 18:15:00   0.19      16401.0  United Kingdom
#
# [86 rows x 8 columns]

# %% [markdown]
# check StockCode

# %%
stockcode_counts = df.groupby('Description').agg(number_stockcode=('StockCode', pd.Series.nunique)).reset_index()

# %%
multiple_stockcode = stockcode_counts[stockcode_counts['number_stockcode'] > 1]

# %%
multiple_stockcode = multiple_stockcode.sort_values("number_stockcode", ascending=False)

# %%
multiple_stockcode
# Out:
#                           Description  number_stockcode
# 2394   METAL SIGN,CUPCAKE SINGLE HOOK                 3
# 996      COLOURING PENCILS BROWN TUBE                 3
# 2467     MODERN CHRISTMAS TREE CANDLE                 2
# 4201          This is a test product.                 2
# 3988    SQUARE CHERRY BLOSSOM CABINET                 2
# 3324         RETRO PLASTIC POLKA TRAY                 2
# 3322         RETRO PLASTIC DAISY TRAY                 2
# 3321          RETRO PLASTIC 70'S TRAY                 2
# 2922       PINK FLOWERS RABBIT EASTER                 2
# 2913    PINK FLOCK GLASS CANDLEHOLDER                 2
# 2907    PINK FAIRY CAKE CUSHION COVER                 2
# 156      ACRYLIC JEWEL SNOWFLAKE,BLUE                 2
# 531     BLUE FLOCK GLASS CANDLEHOLDER                 2
# 1630              FROSTED WHITE BASE                  2
# 1607    FRENCH LATTICE CUSHION COVER                  2
# 1604     FRENCH FLORAL CUSHION COVER                  2
# 1278  EAU DE NILE JEWELLED PHOTOFRAME                 2
# 1000          COLUMBIAN CANDLE ROUND                  2
# 999            COLUMBIAN CANDLE ROUND                 2
# 998        COLUMBIAN CANDLE RECTANGLE                 2
# 4363      WHITE BAMBOO RIBS LAMPSHADE                 2

# %%
df[df['Description'] == 'METAL SIGN,CUPCAKE SINGLE HOOK']
# Out:
#        Invoice StockCode                     Description  Quantity  \
# 7255    490017    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 7256    490017    82613B  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 7258    490017    82613C  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 13875   490503    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         3
# 19293   490972    82613A  METAL SIGN,CUPCAKE SINGLE HOOK        16
# ...        ...       ...                             ...       ...
# 477522  577058    82613C  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 477524  577058    82613B  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 477589  577062    82613C  METAL SIGN,CUPCAKE SINGLE HOOK         8
# 482589  577479    82613C  METAL SIGN,CUPCAKE SINGLE HOOK         8
# 531553  580956    82613B  METAL SIGN,CUPCAKE SINGLE HOOK         1
#
#                InvoiceDate  Price  Customer ID         Country
# 7255   2009-12-03 12:31:00   1.25      14159.0  United Kingdom
# 7256   2009-12-03 12:31:00   1.25      14159.0  United Kingdom
# 7258   2009-12-03 12:31:00   1.25      14159.0  United Kingdom
# 13875  2009-12-06 14:00:00   1.25      14548.0  United Kingdom
# 19293  2009-12-08 16:40:00   1.25      14911.0            EIRE
# ...                    ...    ...          ...             ...
# 477522 2011-11-17 14:29:00   1.25      18122.0  United Kingdom
# 477524 2011-11-17 14:29:00   1.25      18122.0  United Kingdom
# 477589 2011-11-17 14:40:00   1.25      18221.0  United Kingdom
# 482589 2011-11-20 11:34:00   1.25      14911.0            EIRE
# 531553 2011-12-06 14:23:00   1.25      17841.0  United Kingdom
#
# [252 rows x 8 columns]

# %%
def fix_duplicates_stockcode(df):
    df['StockCode'] = df.groupby('Description')['StockCode'].transform('first')
    return df

# %%
df = fix_duplicates_stockcode(df)

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# check StockCode (again)

# %%
stockcode_counts = df.groupby('Description').agg(number_stockcode=('StockCode', pd.Series.nunique)).reset_index()

# %%
multiple_stockcode = stockcode_counts[stockcode_counts['number_stockcode'] > 1]

# %%
multiple_stockcode = multiple_stockcode.sort_values("number_stockcode", ascending=False)

# %%
multiple_stockcode
# Out:
# Empty DataFrame
# Columns: [Description, number_stockcode]
# Index: []

# %%
df[df['Description'] == 'METAL SIGN,CUPCAKE SINGLE HOOK']
# Out:
#        Invoice StockCode                     Description  Quantity  \
# 7255    490017    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 7256    490017    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 7258    490017    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 13875   490503    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         3
# 19293   490972    82613A  METAL SIGN,CUPCAKE SINGLE HOOK        16
# ...        ...       ...                             ...       ...
# 477522  577058    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 477524  577058    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         1
# 477589  577062    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         8
# 482589  577479    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         8
# 531553  580956    82613A  METAL SIGN,CUPCAKE SINGLE HOOK         1
#
#                InvoiceDate  Price  Customer ID         Country
# 7255   2009-12-03 12:31:00   1.25      14159.0  United Kingdom
# 7256   2009-12-03 12:31:00   1.25      14159.0  United Kingdom
# 7258   2009-12-03 12:31:00   1.25      14159.0  United Kingdom
# 13875  2009-12-06 14:00:00   1.25      14548.0  United Kingdom
# 19293  2009-12-08 16:40:00   1.25      14911.0            EIRE
# ...                    ...    ...          ...             ...
# 477522 2011-11-17 14:29:00   1.25      18122.0  United Kingdom
# 477524 2011-11-17 14:29:00   1.25      18122.0  United Kingdom
# 477589 2011-11-17 14:40:00   1.25      18221.0  United Kingdom
# 482589 2011-11-20 11:34:00   1.25      14911.0            EIRE
# 531553 2011-12-06 14:23:00   1.25      17841.0  United Kingdom
#
# [252 rows x 8 columns]

# %% [markdown]
# check unique value (again)

# %%
for i in df.columns:
    print('Columns name: ', i)
    print('Unique value: ', df[i].unique())
    print('Count unique value: ', df[i].nunique())
    print('-'*10)
# Out:
# Columns name:  Invoice
# Unique value:  [489434 489435 489436 ... 581585 581586 581587]
# Count unique value:  36969
# ----------
# Columns name:  StockCode
# Unique value:  [85048 '79323P' '79323W' ... 23562 23561 23843]
# Count unique value:  4608
# ----------
# Columns name:  Description
# Unique value:  ['15CM CHRISTMAS GLASS BALL 20 LIGHTS' 'PINK CHERRY LIGHTS'
#  ' WHITE CHERRY LIGHTS' ... 'SET OF 6 RIBBONS PERFECTLY PRETTY  '
#  'SET OF 6 RIBBONS PARTY' 'PAPER CRAFT , LITTLE BIRDIE']
# Count unique value:  4608
# ----------
# Columns name:  Quantity
# Unique value:  [   12    48    24    10    18     3    16     4     2     6     8     1
#     28    30    60    32    56     9    25    36    20   576   288    27
#     64   160     5    72    50    54     7   800    11    58   192    96
#    144   100   180   216    15   240   108    33    90    81    17    40
#     13    21   120   200   168    19   280   128    80   300   450    14
#     61   480    46   504    45  4320  5184  4008    22   600   505   500
#     23    47   432   252    75   360   107    49    42    66    34    52
#    400    70   936    35   256  1500   320   130  1002    26  1080    29
#     67   960   864   150   126   468   336  3000    38   208   334   124
#    125   117    39    55    78    77   350   526    98   112    59    37
#    408  1440   832   624   204   198   608   224    43    65   720   271
#     41   264   225   104   163   187   312   164   110   250   284    89
#    118  6012   866  6144  2040  2520  3888  5280  4800  6768  9312   384
#     44   132   229    62    82   114   156   460    84   374   190   484
#  19152  3312  1344  2504  1968   482  4176  2880  6696  1200  1800  1400
#  1.96000e+00 9.98000e+00 4.67000e+00 1.16700e+01 3.12000e+00 1.49600e+01
#  2.91300e+01 1.32900e+01 3.32900e+01 6.88080e+02 9.13000e+00 4.90250e+02
#  3.26000e+00 1.12000e+00 6.67000e+00 2.85000e+00 4.98000e+00 5.66000e+00
#  3.58000e+00 5.35000e+00 3.57000e+00 3.89000e+00 3.97000e+00 5.68000e+00
#  3.15595e+03 1.52780e+02 3.22200e+01 1.20000e+02 2.40000e+02 1.99600e+01
#  1.46000e+00 6.35010e+02 5.99500e+02 2.83020e+02 3.39020e+02 7.43620e+02
#  3.94932e+03 2.11874e+03 1.66500e+01 2.08000e+01 3.92000e+00 4.64900e+02
#  6.38300e+02 1.45500e+01 3.13000e+00 1.67000e+00 4.16106e+03 1.71000e+00
#  9.01580e+02 2.48000e+00 1.11000e+00 9.08160e+02 4.04600e+01 4.24060e+02
#  5.49340e+02 5.17000e+00 2.67000e+00 9.20000e-01 1.50036e+03 8.50500e+02
#  3.00000e+02 6.71000e+00 2.04000e+00 1.27006e+03 1.52676e+03 5.13000e+00
#  7.84000e+00 2.42000e+00 1.01000e+00 3.16000e+00 4.70000e+00 2.19500e+02
#  1.59926e+03 1.86000e+00 3.30000e+00 1.33500e+01 4.76000e+00]
# Count unique value:  665
# ----------
# Columns name:  Customer ID
# Unique value:  [13085. 13078. 15362. ... 15520. 13298. 12713.]
# Count unique value:  5878
# ----------
# Columns name:  Country
# Unique value:  ['United Kingdom' 'France' 'USA' 'Belgium' 'Australia' 'EIRE' 'Germany'
#  'Portugal' 'Denmark' 'Netherlands' 'Poland' 'Channel Islands' 'Spain'
#  'Cyprus' 'Greece' 'Norway' 'Austria' 'Sweden' 'United Arab Emirates'
#  'Finland' 'Italy' 'Switzerland' 'Japan' 'Unspecified' 'Nigeria' 'Malta'
#  'RSA' 'Singapore' 'Bahrain' 'Thailand' 'Israel' 'Lithuania' 'West Indies'
#  'Korea' 'Brazil' 'Canada' 'Iceland' 'Lebanon' 'Saudi Arabia'
#  'Czech Republic' 'European Community']
# Count unique value:  41
# ----------

# %% [markdown]
# clean Description

# %%
df['Description'] = df['Description'].str.replace(',', '')

# %%
df['Description'] = df['Description'].str.replace('*', '')

# %%
df['Description'] = df['Description'].str.strip()

# %%
for n in range(2,11,1):
    df['Description'] = df['Description'].str.replace(' '*n, '')

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom

# %% [markdown]
# # 3. Manipulate cost for optimization model

# %%
np.random.seed(42)
df['profit_margin'] = np.random.uniform(0.01, 0.5, size=len(df))

# %%
df['Cost_price'] = df['Price'] * (1 - df['profit_margin'])

# %% [markdown]
# # 4. Export cleaned data

# %%
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041          RECORD FRAME 7" SINGLE SIZE        48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#           InvoiceDate  Price  Customer ID         Country  profit_margin  \
# 0 2009-12-01 07:45:00   6.95      13085.0  United Kingdom       0.193525
# 1 2009-12-01 07:45:00   6.75      13085.0  United Kingdom       0.475850
# 2 2009-12-01 07:45:00   6.75      13085.0  United Kingdom       0.368677
# 3 2009-12-01 07:45:00   2.10      13085.0  United Kingdom       0.303343
# 4 2009-12-01 07:45:00   1.25      13085.0  United Kingdom       0.086449
#
#    Cost_price
# 0    5.605004
# 1    3.538012
# 2    4.261430
# 3    1.462980
# 4    1.141939

# %%
df.to_csv('01. Cleaned_retail_data.csv', sep=',', index=False)
